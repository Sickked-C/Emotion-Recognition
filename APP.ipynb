# %% [markdown]
# THÊM THƯ VIỆN

# %%
import librosa
import librosa.display
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from matplotlib.pyplot import specgram
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
import seaborn as sns
import keras
from keras.callbacks import ReduceLROnPlateau
from keras.models import Sequential
from keras.layers import Dense, Conv1D, LSTM, MaxPooling1D, Flatten, Dropout, BatchNormalization
from keras.utils import to_categorical
from keras.callbacks import ModelCheckpoint
from keras import regularizers
import os
import glob
import pandas as pd
import IPython.display as ipd
import plotly.express as px
import scipy.io.wavfile
import sys
import warnings
if not sys.warnoptions:
    warnings.simplefilter("ignore")
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %% [markdown]
# TIỀN XỬ LÝ DỮ LIỆU

# %%
#Xuất dữ liệu
RAV = 'RAVDESS/audio_speech_actors_01-24/'
dir_list = os.listdir(RAV)

emotion = [] #biểu thị cảm xúc của âm thanh
gender = [] #giới tính của người nói
path = [] #đường dẫn đến file âm thanh tương ứng
feature = []
#Phân tích tên file âm thanh để trích xuất thông tin về cảm xúc và giới tính của người nói.
for i in dir_list:
    fname = os.listdir(RAV + i)
    for f in fname:
        part = f.split('.')[0].split('-')
        emotion.append(int(part[2]))
        temp = int(part[6])
        if temp%2 == 0:
            temp = "female"
        else:
            temp = "male"
        gender.append(temp)
        path.append(RAV + i + '/' + f)

#Xây dựng DataFrame RAV_df từ các thông tin đã trích xuất
RAV_df = pd.DataFrame(emotion)
RAV_df = RAV_df.replace({1:'neutral', 2:'calm', 3:'happy', 4:'sad', 5:'angry', 6:'fear', 7:'disgust', 8:'surprise'})
RAV_df = pd.concat([pd.DataFrame(gender),RAV_df],axis=1)
RAV_df.columns = ['gender','emotion']
RAV_df['labels'] =RAV_df.gender + '_' + RAV_df.emotion
RAV_df['source'] = 'RAVDESS'
RAV_df = pd.concat([RAV_df,pd.DataFrame(path, columns = ['path'])],axis=1)
#Loại bỏ cột 'gender' và hiển thị số lượng mẫu dữ liệu cho mỗi nhãn cảm xúc.
RAV_df = RAV_df.drop(['gender'], axis=1)
RAV_df.labels.value_counts()
# Out:
# labels
# male_calm          96
# male_happy         96
# male_fear          96
# male_disgust       96
# male_angry         96
# male_sad           96
# male_surprise      96
# female_calm        96
# female_happy       96
# female_fear        96
# female_disgust     96
# female_angry       96
# female_surprise    96
# female_sad         96
# male_neutral       48
# female_neutral     48
# Name: count, dtype: int64

# %%
display(RAV_df.head()) #hiển thị các dòng đầu tiên của DataFrame RAV_df
display(RAV_df.describe()) # tóm tắt thống kê của các cột số trong DataFrame RAV_df
# Out:
#   emotion     labels   source  \
# 0    calm  male_calm  RAVDESS
# 1    calm  male_calm  RAVDESS
# 2    calm  male_calm  RAVDESS
# 3    calm  male_calm  RAVDESS
# 4    calm  male_calm  RAVDESS
#
#                                                 path
# 0  /content/drive/MyDrive/Colab Notebooks/DATA/RA...
# 1  /content/drive/MyDrive/Colab Notebooks/DATA/RA...
# 2  /content/drive/MyDrive/Colab Notebooks/DATA/RA...
# 3  /content/drive/MyDrive/Colab Notebooks/DATA/RA...
# 4  /content/drive/MyDrive/Colab Notebooks/DATA/RA...
#        emotion     labels   source  \
# count     1440       1440     1440
# unique       8         16        1
# top       calm  male_calm  RAVDESS
# freq       192         96     1440
#
#                                                      path
# count                                                1440
# unique                                               1440
# top     /content/drive/MyDrive/Colab Notebooks/DATA/RA...
# freq                                                    1

# %% [markdown]
# TRỰC QUAN HÓA DỮ LIỆU

# %%
#Dùng histogram để vẽ biểu đồ miêu tả chung sự phân bố của các nhãn
px_fig = px.histogram(RAV_df, x='emotion', color='emotion', marginal='box', title='Emotion Count')
px_fig.update_layout(bargap=0.2)
px_fig.show()

#Dùng histogram để vẽ biểu đồ miêu tả chi tiết sự phân bố của các nhãn
px_fig = px.histogram(RAV_df, x='labels', color='emotion', marginal='box', title='Label Count')
px_fig.update_layout(bargap=0.2)
px_fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="734043b1-57be-41af-b16f-cad8f592805f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("734043b1-57be-41af-b16f-cad8f592805f")) {                    Plotly.newPlot(                        "734043b1-57be-41af-b16f-cad8f592805f",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"emotion=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"calm","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"calm","offsetgroup":"calm","orientation":"v","showlegend":true,"x":["calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","hovertemplate":"emotion=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"calm","marker":{"color":"#636efa"},"name":"calm","notched":true,"offsetgroup":"calm","showlegend":false,"x":["calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm","calm"],"xaxis":"x2","yaxis":"y2","type":"box"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"emotion=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"neutral" ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="924dda88-2773-49ae-8931-9d63acbb14a9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("924dda88-2773-49ae-8931-9d63acbb14a9")) {                    Plotly.newPlot(                        "924dda88-2773-49ae-8931-9d63acbb14a9",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"emotion=calm\u003cbr\u003elabels=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"calm","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"calm","offsetgroup":"calm","orientation":"v","showlegend":true,"x":["male_calm","male_calm","male_calm","male_calm","male_calm","male_calm","male_calm","male_calm","female_calm","female_calm","female_calm","female_calm","female_calm","female_calm","female_calm","female_calm","male_calm","male_calm","male_calm","male_calm","male_calm","male_calm","male_calm","male_calm","female_calm","female_calm","female_calm","female_calm","female_calm","female_calm","female_calm","female_calm","male_calm","male_calm","male_calm","male_calm","male_calm","male_calm","male_calm","male_calm","female_calm","female_calm","female_calm","female_calm","female_calm","female_calm","female_calm","female_calm","female_calm","female_calm","female_calm","female_calm","female_calm","female_calm","female_calm","female_calm","male_calm","male_calm","male_calm","male_calm","male_calm","male_calm","male_calm","male_calm","male_calm","male_calm","male_calm","male_calm","male_calm","male_calm","male_calm","male_calm","female_calm","female_calm","female_calm","female_calm","female_calm","female_calm","female_calm","female_calm","female_calm","female_calm","female_calm","female_calm","female_calm","female_calm","female_calm","female_calm","male_calm","male_calm","male_calm","male_calm","male_calm","male_calm","male_calm","male_calm","female_calm","female_calm","female_calm","female_calm","female_calm","female_calm","female_calm","female_calm","male_calm","male_calm","male_calm","male_calm","male_calm","male_calm","male_calm","male_calm","male_calm","male_calm","male_calm","male_calm","male_calm","male_calm","male_calm","male_calm","male_calm","male_calm","male_calm","male_calm","male_calm","male_calm","male_calm","male_calm","female_calm","female_calm","female_calm","female_calm","female_calm","female_calm","female_calm","female_calm","male_calm","male_calm","male_calm","male_calm","male_calm","male_calm","male_calm","male_calm","female_calm","female_calm","female_calm","female_calm","female_calm","female_calm","female_calm","female_calm","female_calm","female_calm","female_calm","female_calm","female_calm","female_calm","female_calm","female_calm","female_calm","female_calm","female_calm","female_calm","female_calm","female_calm","female_calm","female_calm","male_calm","male_calm","male_calm","male_calm","male_calm","male_calm","male_calm","male_calm","female_calm","female_calm","female_calm","female_calm","female_calm","female_calm","female_calm","female_calm","male_calm","male_calm","male_calm","male_calm","male_calm","male_calm","male_calm","male_calm"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","hovertemplate":"emotion=calm\u003cbr\u003elabels=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"calm","marker":{"color":"#636efa"},"name":"calm","notched":true,"offsetgroup":"calm","showlegend":false,"x":["male_calm","male_calm","male_calm","male_calm","male_calm","male_calm","male_calm","male_calm","female_calm","female_calm","female_calm","female_calm","female_calm","female_calm","female_calm","female_calm","male_calm","male_calm","male_calm","male_calm","male_calm","male_calm","male_calm","male_calm","female_calm","female_calm","female_c ...

# %%
# Tạo hàm hiển thị đồ thị sóng của giọng nói
# data: dữ liệu; sr : sampling rate; e : emotion
#sr là sampling rate là tần số lấy mẫu. Nó đo lường tần suất mẫu hóa dữ liệu âm thanh và được đo tính bằng Hz
def create_waveplot(data, sr, e):
    plt.figure(figsize=(10, 3))
    plt.title('Biểu đồ sóng cho âm thanh có cảm xúc {}'.format(e), size=15)
    librosa.display.waveshow(data, sr=sr)
    plt.show()

# %%
# Tạo hàm hiển thị đồ thị phổ quang của giọng nói
def create_spectrogram(data, sr, e):
    # Hàm stft chuyển đổi dữ liệu thành biến đổi Fourier ngắn hạn
    X = librosa.stft(data)
    # Chuyển âm thanh về decibel(dB)
    Xdb = librosa.amplitude_to_db(abs(X))
    plt.figure(figsize=(12, 3))
    plt.title('Quang phổ cho âm thanh có cảm xúc {}'.format(e), size=15)
    librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='hz')
    plt.colorbar()

# %%
# Hiển thị biểu đồ sóng và phổ quang miêu tả về âm thanh sợ hãi
emotion='fear'
path = np.array(RAV_df.path[RAV_df.emotion==emotion])[1]
data, sampling_rate = librosa.load(path)
create_waveplot(data, sampling_rate, emotion)
create_spectrogram(data, sampling_rate, emotion)
ipd.Audio(path) # phát lại âm thanh từ đường dẫn đã chọn
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# TĂNG CƯỜNG DỮ LIỆU

# %%
# Hàm làm nhiễu âm thanh
def noise(data):
    noise_amp = 0.035*np.random.uniform()*np.amax(data)
    data = data + noise_amp*np.random.normal(size=data.shape[0])
    return data

# Hàm kéo dài âm thanh
def stretch(data, rate=0.8):
    return librosa.effects.time_stretch(data, rate = rate)

# Hàm nhấn mạnh/thấp âm thanh
def pitch(data, sampling_rate, pitch_factor=0.7):
   # return librosa.effects.pitch_shift(data, sampling_rate, pitch_factor)
    return librosa.effects.pitch_shift(y=data, sr=sampling_rate, n_steps=pitch_factor)

path = np.array(RAV_df.path)[1]
data, sample_rate = librosa.load(path)

# %%
# Âm thanh bình thường
plt.figure(figsize=(14,4))
librosa.display.waveshow(y=data, sr=sample_rate)
ipd.Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Âm thanh bị lãm nhiễu
x = noise(data)
plt.figure(figsize=(14,4))
librosa.display.waveshow(y=x, sr=sample_rate)
ipd.Audio(x, rate=sample_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Âm thanh bị kéo dãn
x = stretch(data)
plt.figure(figsize=(14,4))
librosa.display.waveshow(y=x, sr=sample_rate)
ipd.Audio(x, rate=sample_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Âm thanh được nhấn mạnh
x = pitch(data,sample_rate)
plt.figure(figsize=(14,4))
librosa.display.waveshow(y=x, sr=sample_rate)
ipd.Audio(x, rate=sample_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# KHAI THÁC TÍNH NĂNG

# %%
# Hàm trích xuất các đặc trưng từ dữ liệu
def extract_features(data):
    # ZCR: Tần số băng qua không là tốc độ tín hiệu thay đổi từ dương sang 0 sang âm hoặc từ âm sang 0 sang dương
    result = np.array([])
    zcr = np.mean(librosa.feature.zero_crossing_rate(y=data).T, axis=0)
    result=np.hstack((result, zcr))

    # Chroma_stft : Thể hiện phân bố tần số của các nốt nhạc trong tín hiệu âm thanh.
    stft = np.abs(librosa.stft(data))
    chroma_stft = np.mean(librosa.feature.chroma_stft(S=stft, sr=sample_rate).T, axis=0)
    result = np.hstack((result, chroma_stft))

    # MFCC : Là một bộ các đặc trưng được sử dụng phổ biến trong xử lý tín hiệu âm thanh
    mfcc = np.mean(librosa.feature.mfcc(y=data, sr=sample_rate).T, axis=0)
    result = np.hstack((result, mfcc))

    # Root Mean Square Value: Là một đại lượng thể hiện sức mạnh trung bình của tín hiệu âm thanh trong mỗi cửa sổ thời gian
    rms = np.mean(librosa.feature.rms(y=data).T, axis=0)
    result = np.hstack((result, rms))

    # MelSpectogram : là biểu diễn trực quan của phổ tần số của tín hiệu âm thanh,
    #trong đó các tần số được biểu diễn trên trục y dưới dạng các băng thông mel thay vì Hz.
    mel = np.mean(librosa.feature.melspectrogram(y=data, sr=sample_rate).T, axis=0)
    result = np.hstack((result, mel))

    return result
# Hàm trích xuất các đặc trưng từ dữ liệu âm-thanh
def get_features(path):
    # Xử lý thời lượng và độ lệch được sử dụng để xử lý phần không có âm thanh khi bắt đầu và kết thúc của mỗi tệp âm thanh
    data, sample_rate = librosa.load(path, duration=2.5, offset=0.6)

    # Với không tăng cường
    res1 = extract_features(data)
    result = np.array(res1)

    # làm nhiễu dữ liệu
    noise_data = noise(data)
    res2 = extract_features(noise_data)
    result = np.vstack((result, res2))

    # kéo dãn và nhấn mạnh/thấp của âm thanh
    new_data = stretch(data)
    data_stretch_pitch = pitch(new_data, sample_rate)
    res3 = extract_features(data_stretch_pitch)
    result = np.vstack((result, res3))

    return result

# %%
# Thêm cảm xúc 3 lần vì đã thực hiện 3 kỹ thuật
# tăng cường trên mỗi tệp âm thanh
X, Y = [], []
for path, emotion in zip(RAV_df.path, RAV_df.emotion):
    feature = get_features(path)
    for ele in feature:
        X.append(ele)
        Y.append(emotion)

# %%
#mã trả về kích thước của X, Y và số lượng đường dẫn âm thanh trong RAV_df
len(X), len(Y), RAV_df.path.shape
# Out:
# (4320, 4320, (1440,))

# %%
Features = pd.DataFrame(X)
Features['labels'] = Y
Features.to_csv('features.csv', index=False)

# %%
#Hiển thị một số dòng đầu tiên và thống kê
display(Features.head())
display(Features.describe())
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.178354  0.810467  0.707073  0.600535  0.604771  0.648012  0.626874
# 1  0.254928  0.838237  0.722650  0.681089  0.699075  0.753572  0.677543
# 2  0.155049  0.798478  0.703555  0.579224  0.577010  0.626987  0.629427
# 3  0.190448  0.694625  0.730583  0.733133  0.739128  0.721110  0.699378
# 4  0.306704  0.775796  0.828816  0.825989  0.819444  0.821974  0.747088
#
#           7         8         9  ...       153       154       155       156  \
# 0  0.597224  0.663339  0.611452  ...  0.000007  0.000007  0.000005  0.000006
# 1  0.652888  0.718054  0.634485  ...  0.000012  0.000011  0.000010  0.000010
# 2  0.593089  0.621310  0.578498  ...  0.000001  0.000001  0.000002  0.000001
# 3  0.653086  0.710711  0.744858  ...  0.000003  0.000003  0.000002  0.000001
# 4  0.692631  0.760876  0.801307  ...  0.000007  0.000007  0.000007  0.000006
#
#             157           158           159           160           161  \
# 0  4.284742e-06  3.988984e-06  2.407329e-06  8.899194e-07  5.797154e-08
# 1  8.585972e-06  8.684004e-06  6.904134e-06  5.637219e-06  4.799599e-06
# 2  1.141063e-06  1.048467e-06  8.726571e-07  4.501753e-07  2.529664e-08
# 3  8.644034e-07  6.660677e-07  4.428955e-07  2.127365e-07  1.714209e-08
# 4  5.165733e-06  4.927940e-06  4.716822e-06  4.549208e-06  4.200436e-06
#
#    labels
# 0    calm
# 1    calm
# 2    calm
# 3    calm
# 4    calm
#
# [5 rows x 163 columns]
#                0            1            2            3            4    \
# count  4320.000000  4320.000000  4320.000000  4320.000000  4320.000000
# mean      0.211177     0.628500     0.631603     0.636588     0.646592
# std       0.068980     0.088311     0.097703     0.100863     0.102593
# min       0.060091     0.339261     0.287325     0.274444     0.261164
# 25%       0.154690     0.570052     0.565036     0.565821     0.576083
# 50%       0.202417     0.632175     0.637391     0.642661     0.653188
# 75%       0.267959     0.692648     0.704537     0.712670     0.723854
# max       0.390842     0.866057     0.887291     0.889163     0.898633
#
#                5            6            7            8            9    ...  \
# count  4320.000000  4320.000000  4320.000000  4320.000000  4320.000000  ...
# mean      0.635263     0.606287     0.601146     0.620220     0.637488  ...
# std       0.104879     0.091370     0.078730     0.080801     0.079429  ...
# min       0.263645     0.269483     0.262952     0.242572     0.269638  ...
# 25%       0.565414     0.550477     0.553622     0.568618     0.586180  ...
# 50%       0.642311     0.615547     0.609335     0.627020     0.644250  ...
# 75%       0.710720     0.670709     0.656887     0.678384     0.693579  ...
# max       0.911725     0.895273     0.813966     0.825857     0.868190  ...
#
#                 152           153           154           155           156  \
# count  4.320000e+03  4.320000e+03  4.320000e+03  4.320000e+03  4.320000e+03
# mean   1.687769e-03  1.695272e-03  1.744547e-03  1.772638e-03  1.820415e-03
# std    5.659185e-03  5.622175e-03  5.830910e-03  5.993766e-03  6.242104e-03
# min    2.135293e-08  1.692828e-08  2.129181e-08  2.400353e-08  2.899570e-08
# 25%    2.967655e-05  2.981582e-05  3.093782e-05  3.203802e-05  3.531418e-05
# 50%    1.695384e-04  1.721933e-04  1.728666e-04  1.829241e-04  1.883590e-04
# 75%    8.648130e-04  8.568637e-04  9.242036e-04  9.088810e-04  9.288893e-04
# max    8.610280e-02  8.315963e-02  8.924413e-02  9.696110e-02  1.161076e-01
#
#                 157           158           159           160           161
# count  4.320000e+03  4.320000e+03  4.320000e+03  4.320000e+03  4.320000e+03
# mean   1.858695e-03  1.858564e-03  1.813284e-03  1.318017e-03  6.875854e-04
# std    6.311353e-03  6.169716e-03  5.883739e-03  4.785613e-03  3.724794e-03
# min    2.325147e-08  6.041341e-08  7.742907e-08  3.496952e-08  2.159540e-09
# 25%    3.525084e-05  3.547359e-05  3.423280e-05  2.062771e-05  2.071623e-06
# 50%    1.846988e-04  1.897374e-04  1.850571e-04  1.196603e-04  1.520357e-05
# 75%    9.239062e-04  9.378672e-04  9.342572e-04  6.225054e-04  1.207861e-04
# max    1.063900e-01  8.939405e-02  8.721388e-02  8.220780e-02  7.137717e-02
#
# [8 rows x 162 columns]

# %% [markdown]
# Xây dựng mô hình

# %%
# Xác định dữ liệu đầu vào và đầu ra
X = Features.iloc[:, :-1].values  # Ma trận đặc trưng
Y = Features['labels'].values     # Vector nhãn

# Mã hóa nhãn sang dạng one-hot
encoder = OneHotEncoder()
Y_encoded = encoder.fit_transform(np.array(Y).reshape(-1,1)).toarray()

# Phân chia dữ liệu thành tập huấn luyện và tập kiểm tra
x_train, x_test, y_train, y_test = train_test_split(X, Y_encoded, random_state=0, shuffle=True)

# Chuẩn hóa dữ liệu
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# Mở rộng số chiều của dữ liệu
x_train_reshaped = np.expand_dims(x_train_scaled, axis=2)  # Tập huấn luyện
x_test_reshaped = np.expand_dims(x_test_scaled, axis=2)    # Tập kiểm tra

# %%
# Mô hình LSTM
model_lstm = Sequential()

model_lstm.add(Conv1D(128, kernel_size=3, strides=1, padding='same', activation='relu'))
model_lstm.add(BatchNormalization())
model_lstm.add(MaxPooling1D(pool_size=3, strides=2, padding='same'))

model_lstm.add(Conv1D(64, kernel_size=3, strides=1, padding='same', activation='relu'))
model_lstm.add(BatchNormalization())
model_lstm.add(MaxPooling1D(pool_size=3, strides=2, padding='same'))

model_lstm.add(Conv1D(32, kernel_size=3, strides=1, padding='same', activation='relu'))
model_lstm.add(BatchNormalization())
model_lstm.add(MaxPooling1D(pool_size=3, strides=2, padding='same'))

model_lstm.add(Flatten())
model_lstm.add(Dense(128, activation='relu'))
model_lstm.add(BatchNormalization())
model_lstm.add(Dropout(0.2))

model_lstm.add(Dense(64, activation='relu'))
model_lstm.add(Dense(32, activation='relu'))

model_lstm.add(Dense(8, activation='softmax'))
model_lstm.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

model_lstm.build(input_shape=(None, x_train_reshaped.shape[1], 1))
model_lstm.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_7 (Conv1D)           (None, 162, 128)          512
#
#  batch_normalization_4 (Bat  (None, 162, 128)          512
#  chNormalization)
#
#  max_pooling1d_7 (MaxPoolin  (None, 81, 128)           0
#  g1D)
#
#  conv1d_8 (Conv1D)           (None, 81, 64)            24640
#
#  batch_normalization_5 (Bat  (None, 81, 64)            256
#  chNormalization)
#
#  max_pooling1d_8 (MaxPoolin  (None, 41, 64)            0
#  g1D)
#
#  conv1d_9 (Conv1D)           (None, 41, 32)            6176
#
#  batch_normalization_6 (Bat  (None, 41, 32)            128
#  chNormalization)
#
#  max_pooling1d_9 (MaxPoolin  (None, 21, 32)            0
#  g1D)
#
#  flatten_2 (Flatten)         (None, 672)               0
#
#  dense_6 (Dense)             (None, 128)               86144
#
#  batch_normalization_7 (Bat  (None, 128)               512
#  chNormalization)
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_7 (Dense)             (None, 64)                8256
#
#  dense_8 (Dense)             (None, 32)                2080
#
#  dense_9 (Dense)             (None, 8)                 264
#
# =================================================================
# Total params: 129480 (505.78 KB)
# Trainable params: 128776 (503.03 KB)
# Non-trainable params: 704 (2.75 KB)
# _________________________________________________________________

# %%
# Mô hình CNN
model_cnn = Sequential()
model_cnn.add(Conv1D(256, kernel_size=5, strides=1, padding='same', activation='relu', input_shape=(x_train.shape[1], 1)))
model_cnn.add(MaxPooling1D(pool_size=5, strides = 2, padding = 'same'))

model_cnn.add(Conv1D(128, kernel_size=5, strides=1, padding='same', activation='relu'))
model_cnn.add(MaxPooling1D(pool_size=5, strides = 2, padding = 'same'))

model_cnn.add(Conv1D(64, kernel_size=5, strides=1, padding='same', activation='relu'))
model_cnn.add(MaxPooling1D(pool_size=5, strides = 2, padding = 'same'))
model_cnn.add(Dropout(0.2))

model_cnn.add(Conv1D(32, kernel_size=5, strides=1, padding='same', activation='relu'))
model_cnn.add(MaxPooling1D(pool_size=5, strides = 2, padding = 'same'))

model_cnn.add(Flatten())
model_cnn.add(Dense(units=16, activation='relu'))
model_cnn.add(Dropout(0.3))

model_cnn.add(Dense(units=8, activation='softmax'))
model_cnn.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

model_cnn.build(input_shape=(None, x_train.shape[1], 1))
model_cnn.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_10 (Conv1D)          (None, 162, 256)          1536
#
#  max_pooling1d_10 (MaxPooli  (None, 81, 256)           0
#  ng1D)
#
#  conv1d_11 (Conv1D)          (None, 81, 128)           163968
#
#  max_pooling1d_11 (MaxPooli  (None, 41, 128)           0
#  ng1D)
#
#  conv1d_12 (Conv1D)          (None, 41, 64)            41024
#
#  max_pooling1d_12 (MaxPooli  (None, 21, 64)            0
#  ng1D)
#
#  dropout_4 (Dropout)         (None, 21, 64)            0
#
#  conv1d_13 (Conv1D)          (None, 21, 32)            10272
#
#  max_pooling1d_13 (MaxPooli  (None, 11, 32)            0
#  ng1D)
#
#  flatten_3 (Flatten)         (None, 352)               0
#
#  dense_10 (Dense)            (None, 16)                5648
#
#  dropout_5 (Dropout)         (None, 16)                0
#
#  dense_11 (Dense)            (None, 8)                 136
#
# =================================================================
# Total params: 222584 (869.47 KB)
# Trainable params: 222584 (869.47 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Huấn luyện mô hình LSTM
history_lstm = model_lstm.fit(x_train_reshaped, y_train, batch_size=64, epochs=50, validation_data=(x_test_reshaped, y_test),
                               callbacks=[ReduceLROnPlateau(factor=0.4, patience=4, min_lr=0.0000001)])
# Out:
# Epoch 1/50
# 51/51 [==============================] - 10s 27ms/step - loss: 1.9133 - accuracy: 0.2707 - val_loss: 2.0278 - val_accuracy: 0.2194 - lr: 0.0010
# Epoch 2/50
# 51/51 [==============================] - 0s 9ms/step - loss: 1.6504 - accuracy: 0.3864 - val_loss: 1.9970 - val_accuracy: 0.2176 - lr: 0.0010
# Epoch 3/50
# 51/51 [==============================] - 0s 9ms/step - loss: 1.5149 - accuracy: 0.4306 - val_loss: 1.9627 - val_accuracy: 0.2343 - lr: 0.0010
# Epoch 4/50
# 51/51 [==============================] - 0s 9ms/step - loss: 1.4015 - accuracy: 0.4707 - val_loss: 1.9446 - val_accuracy: 0.2324 - lr: 0.0010
# Epoch 5/50
# 51/51 [==============================] - 0s 10ms/step - loss: 1.2830 - accuracy: 0.5160 - val_loss: 2.0747 - val_accuracy: 0.2102 - lr: 0.0010
# Epoch 6/50
# 51/51 [==============================] - 0s 9ms/step - loss: 1.1805 - accuracy: 0.5725 - val_loss: 2.0002 - val_accuracy: 0.2528 - lr: 0.0010
# Epoch 7/50
# 51/51 [==============================] - 1s 14ms/step - loss: 1.1061 - accuracy: 0.5892 - val_loss: 2.0651 - val_accuracy: 0.2639 - lr: 0.0010
# Epoch 8/50
# 51/51 [==============================] - 1s 14ms/step - loss: 1.0404 - accuracy: 0.6086 - val_loss: 1.8847 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 9/50
# 51/51 [==============================] - 1s 14ms/step - loss: 0.9575 - accuracy: 0.6531 - val_loss: 1.5638 - val_accuracy: 0.4213 - lr: 0.0010
# Epoch 10/50
# 51/51 [==============================] - 1s 13ms/step - loss: 0.9031 - accuracy: 0.6731 - val_loss: 1.2549 - val_accuracy: 0.5278 - lr: 0.0010
# Epoch 11/50
# 51/51 [==============================] - 1s 14ms/step - loss: 0.8385 - accuracy: 0.6870 - val_loss: 1.3086 - val_accuracy: 0.5000 - lr: 0.0010
# Epoch 12/50
# 51/51 [==============================] - 1s 10ms/step - loss: 0.7688 - accuracy: 0.7179 - val_loss: 1.6649 - val_accuracy: 0.4620 - lr: 0.0010
# Epoch 13/50
# 51/51 [==============================] - 0s 10ms/step - loss: 0.7265 - accuracy: 0.7389 - val_loss: 1.2403 - val_accuracy: 0.5556 - lr: 0.0010
# Epoch 14/50
# 51/51 [==============================] - 0s 10ms/step - loss: 0.6819 - accuracy: 0.7500 - val_loss: 1.7874 - val_accuracy: 0.4787 - lr: 0.0010
# Epoch 15/50
# 51/51 [==============================] - 0s 9ms/step - loss: 0.6237 - accuracy: 0.7836 - val_loss: 1.5018 - val_accuracy: 0.5593 - lr: 0.0010
# Epoch 16/50
# 51/51 [==============================] - 0s 10ms/step - loss: 0.5728 - accuracy: 0.7904 - val_loss: 1.3072 - val_accuracy: 0.5667 - lr: 0.0010
# Epoch 17/50
# 51/51 [==============================] - 0s 9ms/step - loss: 0.5401 - accuracy: 0.8102 - val_loss: 1.3807 - val_accuracy: 0.5620 - lr: 0.0010
# Epoch 18/50
# 51/51 [==============================] - 0s 9ms/step - loss: 0.4455 - accuracy: 0.8429 - val_loss: 1.1385 - val_accuracy: 0.6222 - lr: 4.0000e-04
# Epoch 19/50
# 51/51 [==============================] - 0s 9ms/step - loss: 0.3488 - accuracy: 0.8806 - val_loss: 1.1276 - val_accuracy: 0.6315 - lr: 4.0000e-04
# Epoch 20/50
# 51/51 [==============================] - 0s 9ms/step - loss: 0.3552 - accuracy: 0.8735 - val_loss: 1.0716 - val_accuracy: 0.6407 - lr: 4.0000e-04
# Epoch 21/50
# 51/51 [==============================] - 1s 10ms/step - loss: 0.3175 - accuracy: 0.8895 - val_loss: 1.1253 - val_accuracy: 0.6398 - lr: 4.0000e-04
# Epoch 22/50
# 51/51 [==============================] - 0s 10ms/step - loss: 0.2977 - accuracy: 0.9003 - val_loss: 1.2397 - val_accuracy: 0.6231 - lr: 4.0000e-04
# Epoch 23/50
# 51/51 [==============================] - 1s 10ms/step - loss: 0.2679 - accuracy: 0.9062 - val_loss: 1.2763 - val_accuracy: 0.6037 - lr: 4.0000e-04
# Epoch 24/50
# 51/51 [==============================] - 0s 9ms/step - loss: 0.2586 - accuracy: 0.9096 - val_loss: 1.0809 - val_accuracy: 0.6611 - lr: 4.0000e-04
# Epoch 25/50
# 51/51 [==============================] - 0s 10ms/step - loss: 0.2126 - accuracy: 0.9318 - val_loss: 1.0515 - val_accuracy: 0.6685 - lr: 1.6000e-04
# Epoch 26/50
# 51/51 [==============================] - 0s 9ms/step - loss: 0.1950 - accuracy: 0.9367 - val_loss: 1.1043 - val_accuracy: 0.6611 - lr: 1.6000e-04
# Epoch 27/50
# 51/51 [==============================] - 1s 10ms/step - loss: 0.2066 - accuracy: 0.9238 - val_loss: 1.0994 - val_accuracy: 0.6667 - lr: 1.6000e-04
# Epoch 28/50
# 51/51 [==============================] - 0s 9ms/step - loss: 0.1780 - accuracy: 0.9426 - val_loss: 1.0764 - val_accuracy: 0.6731 - lr: 1.6000e-04
# Epoch 29/50
# 51/51 [==============================] - 0s 9ms/step - loss: 0.1791 - accuracy: 0.9444 - val_loss: 1.1362 - val_accuracy: 0.6648 - lr: 1.6000e-04
# Epoch 30/50
# 51/51 [==============================] - 0s 9ms/step - loss: 0.1754 - accuracy: 0.9448 - val_loss: 1.1396 - val_accuracy: 0.6620 - lr: 6.4000e-05
# Epoch 31/50
# 51/51 [==============================] - 1s 10ms/step - loss: 0.1641 - accuracy: 0.9503 - val_loss: 1.1217 - val_accuracy: 0.6685 - lr: 6.4000e-05
# Epoch 32/50
# 51/51 [==============================] - 1s 13ms/step - loss: 0.1606 - accuracy: 0.9503 - val_loss: 1.1048 - val_accuracy: 0.6722 - lr: 6.4000e-05
# Epoch 33/50
# 51/51 [==============================] - 1s 13ms/step - loss: 0.1548 - accuracy: 0.9537 - val_loss: 1.1252 - val_accuracy: 0.6694 - lr: 6.4000e-05
# Epoch 34/50
# 51/51 [==============================] - 1s 13ms/step - loss: 0.1384 - accuracy: 0.9586 - val_loss: 1.1227 - val_accuracy: 0.6676 - lr: 2.5600e-05
# Epoch 35/50
# 51/51 [==============================] - 1s 13ms/step - loss: 0.1453 - accuracy: 0.9574 - val_loss: 1.1208 - val_accuracy: 0.6722 - lr: 2.5600e-05
# Epoch 36/50
# 51/51 [==============================] - 1s 15ms/step - loss: 0.1447 - accuracy: 0.9568 - val_loss: 1.1200 - val_accuracy: 0.6731 - lr: 2.5600e-05
# Epoch 37/50
# 51/51 [==============================] - 1s 13ms/step - loss: 0.1470 - accuracy: 0.9540 - val_loss: 1.1190 - val_accuracy: 0.6778 - lr: 2.5600e-05
# Epoch 38/50
# 51/51 [==============================] - 1s 10ms/step - loss: 0.1345 - accuracy: 0.9645 - val_loss: 1.1198 - val_accuracy: 0.6741 - lr: 1.0240e-05
# Epoch 39/50
# 51/51 [==============================] - 1s 10ms/step - loss: 0.1460 - accuracy: 0.9549 - val_loss: 1.1226 - val_accuracy: 0.6750 - lr: 1.0240e-05
# Epoch 40/50
# 51/51 [==============================] - 0s 10ms/step - loss: 0.1476 - accuracy: 0.9531 - val_loss: 1.1241 - val_accuracy: 0.6796 - lr: 1.0240e-05
# Epoch 41/50
# 51/51 [==============================] - 0s 10ms/step - loss: 0.1453 - accuracy: 0.9540 - val_loss: 1.1250 - val_accuracy: 0.6787 - lr: 1.0240e-05
# Epoch 42/50
# 51/51 [==============================] - 0s 9ms/step - loss: 0.1288 - accuracy: 0.9651 - val_loss: 1.1254 - val_accuracy: 0.6796 - lr: 4.0960e-06
# Epoch 43/50
# 51/51 [==============================] - 1s 10ms/step - loss: 0.1385 - accuracy: 0.9556 - val_loss: 1.1240 - val_accuracy: 0.6778 - lr: 4.0960e-06
# Epoch 44/50
# 51/51 [==============================] - 0s 10ms/step - loss: 0.1364 - accuracy: 0.9608 - val_loss: 1.1236 - val_accuracy: 0.6796 - lr: 4.0960e-06
# Epoch 45/50
# 51/51 [==============================] - 0s 10ms/step - loss: 0.1355 - accuracy: 0.9605 - val_loss: 1.1224 - val_accuracy: 0.6815 - lr: 4.0960e-06
# Epoch 46/50
# 51/51 [==============================] - 0s 9ms/step - loss: 0.1325 - accuracy: 0.9577 - val_loss: 1.1228 - val_accuracy: 0.6796 - lr: 1.6384e-06
# Epoch 47/50
# 51/51 [==============================] - 1s 10ms/step - loss: 0.1327 - accuracy: 0.9620 - val_loss: 1.1242 - val_accuracy: 0.6815 - lr: 1.6384e-06
# Epoch 48/50
# 51/51 [==============================] - 0s 9ms/step - loss: 0.1357 - accuracy: 0.9617 - val_loss: 1.1251 - val_accuracy: 0.6806 - lr: 1.6384e-06
# Epoch 49/50
# 51/51 [==============================] - 0s 10ms/step - loss: 0.1386 - accuracy: 0.9602 - val_loss: 1.1258 - val_accuracy: 0.6787 - lr: 1.6384e-06
# Epoch 50/50
# 51/51 [==============================] - 0s 9ms/step - loss: 0.1336 - accuracy: 0.9617 - val_loss: 1.1254 - val_accuracy: 0.6806 - lr: 6.5536e-07

# %%
# Huấn luyện mô hình CNN
history_cnn = model_cnn.fit(x_train_reshaped, y_train, batch_size=64, epochs=50, validation_data=(x_test_reshaped, y_test),
                             callbacks=[ReduceLROnPlateau(factor=0.4, patience=4, min_lr=0.0000001)])
# Out:
# Epoch 1/50
# 51/51 [==============================] - 5s 34ms/step - loss: 2.0392 - accuracy: 0.1759 - val_loss: 2.0032 - val_accuracy: 0.2324 - lr: 0.0010
# Epoch 2/50
# 51/51 [==============================] - 0s 8ms/step - loss: 1.9929 - accuracy: 0.2130 - val_loss: 1.9599 - val_accuracy: 0.2593 - lr: 0.0010
# Epoch 3/50
# 51/51 [==============================] - 0s 8ms/step - loss: 1.9528 - accuracy: 0.2380 - val_loss: 1.8733 - val_accuracy: 0.2769 - lr: 0.0010
# Epoch 4/50
# 51/51 [==============================] - 0s 8ms/step - loss: 1.8747 - accuracy: 0.2728 - val_loss: 1.7995 - val_accuracy: 0.2907 - lr: 0.0010
# Epoch 5/50
# 51/51 [==============================] - 0s 8ms/step - loss: 1.8318 - accuracy: 0.2809 - val_loss: 1.7711 - val_accuracy: 0.3167 - lr: 0.0010
# Epoch 6/50
# 51/51 [==============================] - 0s 8ms/step - loss: 1.8083 - accuracy: 0.3031 - val_loss: 1.7489 - val_accuracy: 0.3111 - lr: 0.0010
# Epoch 7/50
# 51/51 [==============================] - 1s 10ms/step - loss: 1.7726 - accuracy: 0.3120 - val_loss: 1.7070 - val_accuracy: 0.3370 - lr: 0.0010
# Epoch 8/50
# 51/51 [==============================] - 0s 8ms/step - loss: 1.7235 - accuracy: 0.3380 - val_loss: 1.6655 - val_accuracy: 0.3574 - lr: 0.0010
# Epoch 9/50
# 51/51 [==============================] - 0s 8ms/step - loss: 1.6909 - accuracy: 0.3386 - val_loss: 1.6373 - val_accuracy: 0.3731 - lr: 0.0010
# Epoch 10/50
# 51/51 [==============================] - 0s 8ms/step - loss: 1.6529 - accuracy: 0.3562 - val_loss: 1.6094 - val_accuracy: 0.3583 - lr: 0.0010
# Epoch 11/50
# 51/51 [==============================] - 0s 8ms/step - loss: 1.6271 - accuracy: 0.3806 - val_loss: 1.5934 - val_accuracy: 0.3833 - lr: 0.0010
# Epoch 12/50
# 51/51 [==============================] - 1s 10ms/step - loss: 1.6106 - accuracy: 0.3864 - val_loss: 1.5486 - val_accuracy: 0.3944 - lr: 0.0010
# Epoch 13/50
# 51/51 [==============================] - 1s 11ms/step - loss: 1.5903 - accuracy: 0.3963 - val_loss: 1.5492 - val_accuracy: 0.4111 - lr: 0.0010
# Epoch 14/50
# 51/51 [==============================] - 1s 12ms/step - loss: 1.5745 - accuracy: 0.3929 - val_loss: 1.5258 - val_accuracy: 0.4185 - lr: 0.0010
# Epoch 15/50
# 51/51 [==============================] - 1s 10ms/step - loss: 1.5160 - accuracy: 0.4167 - val_loss: 1.5029 - val_accuracy: 0.4222 - lr: 0.0010
# Epoch 16/50
# 51/51 [==============================] - 1s 12ms/step - loss: 1.4831 - accuracy: 0.4426 - val_loss: 1.5105 - val_accuracy: 0.4324 - lr: 0.0010
# Epoch 17/50
# 51/51 [==============================] - 1s 12ms/step - loss: 1.4802 - accuracy: 0.4340 - val_loss: 1.4978 - val_accuracy: 0.4250 - lr: 0.0010
# Epoch 18/50
# 51/51 [==============================] - 0s 10ms/step - loss: 1.4448 - accuracy: 0.4469 - val_loss: 1.4507 - val_accuracy: 0.4269 - lr: 0.0010
# Epoch 19/50
# 51/51 [==============================] - 0s 8ms/step - loss: 1.4172 - accuracy: 0.4537 - val_loss: 1.4384 - val_accuracy: 0.4491 - lr: 0.0010
# Epoch 20/50
# 51/51 [==============================] - 0s 8ms/step - loss: 1.3966 - accuracy: 0.4716 - val_loss: 1.4194 - val_accuracy: 0.4500 - lr: 0.0010
# Epoch 21/50
# 51/51 [==============================] - 0s 8ms/step - loss: 1.3638 - accuracy: 0.4830 - val_loss: 1.3941 - val_accuracy: 0.4685 - lr: 0.0010
# Epoch 22/50
# 51/51 [==============================] - 0s 8ms/step - loss: 1.3429 - accuracy: 0.4852 - val_loss: 1.4135 - val_accuracy: 0.4731 - lr: 0.0010
# Epoch 23/50
# 51/51 [==============================] - 0s 8ms/step - loss: 1.3042 - accuracy: 0.5068 - val_loss: 1.3911 - val_accuracy: 0.4657 - lr: 0.0010
# Epoch 24/50
# 51/51 [==============================] - 0s 8ms/step - loss: 1.3080 - accuracy: 0.4948 - val_loss: 1.3941 - val_accuracy: 0.4556 - lr: 0.0010
# Epoch 25/50
# 51/51 [==============================] - 0s 8ms/step - loss: 1.2726 - accuracy: 0.5157 - val_loss: 1.4034 - val_accuracy: 0.4731 - lr: 0.0010
# Epoch 26/50
# 51/51 [==============================] - 0s 8ms/step - loss: 1.2573 - accuracy: 0.5225 - val_loss: 1.3864 - val_accuracy: 0.4898 - lr: 0.0010
# Epoch 27/50
# 51/51 [==============================] - 1s 10ms/step - loss: 1.2476 - accuracy: 0.5336 - val_loss: 1.3656 - val_accuracy: 0.4981 - lr: 0.0010
# Epoch 28/50
# 51/51 [==============================] - 0s 8ms/step - loss: 1.1951 - accuracy: 0.5448 - val_loss: 1.3375 - val_accuracy: 0.5019 - lr: 0.0010
# Epoch 29/50
# 51/51 [==============================] - 0s 8ms/step - loss: 1.1836 - accuracy: 0.5522 - val_loss: 1.3339 - val_accuracy: 0.5130 - lr: 0.0010
# Epoch 30/50
# 51/51 [==============================] - 0s 8ms/step - loss: 1.1424 - accuracy: 0.5651 - val_loss: 1.3166 - val_accuracy: 0.5167 - lr: 0.0010
# Epoch 31/50
# 51/51 [==============================] - 0s 8ms/step - loss: 1.1357 - accuracy: 0.5688 - val_loss: 1.3246 - val_accuracy: 0.5139 - lr: 0.0010
# Epoch 32/50
# 51/51 [==============================] - 0s 8ms/step - loss: 1.1106 - accuracy: 0.5744 - val_loss: 1.3351 - val_accuracy: 0.5074 - lr: 0.0010
# Epoch 33/50
# 51/51 [==============================] - 0s 8ms/step - loss: 1.1114 - accuracy: 0.5818 - val_loss: 1.3091 - val_accuracy: 0.5083 - lr: 0.0010
# Epoch 34/50
# 51/51 [==============================] - 0s 8ms/step - loss: 1.0720 - accuracy: 0.5920 - val_loss: 1.2963 - val_accuracy: 0.5222 - lr: 0.0010
# Epoch 35/50
# 51/51 [==============================] - 0s 8ms/step - loss: 1.0136 - accuracy: 0.6127 - val_loss: 1.3424 - val_accuracy: 0.5093 - lr: 0.0010
# Epoch 36/50
# 51/51 [==============================] - 0s 8ms/step - loss: 0.9997 - accuracy: 0.6262 - val_loss: 1.2855 - val_accuracy: 0.5324 - lr: 0.0010
# Epoch 37/50
# 51/51 [==============================] - 0s 8ms/step - loss: 1.0111 - accuracy: 0.6123 - val_loss: 1.3270 - val_accuracy: 0.5065 - lr: 0.0010
# Epoch 38/50
# 51/51 [==============================] - 0s 9ms/step - loss: 0.9736 - accuracy: 0.6265 - val_loss: 1.2477 - val_accuracy: 0.5435 - lr: 0.0010
# Epoch 39/50
# 51/51 [==============================] - 0s 8ms/step - loss: 0.9514 - accuracy: 0.6370 - val_loss: 1.2569 - val_accuracy: 0.5370 - lr: 0.0010
# Epoch 40/50
# 51/51 [==============================] - 0s 8ms/step - loss: 0.9548 - accuracy: 0.6336 - val_loss: 1.2895 - val_accuracy: 0.5296 - lr: 0.0010
# Epoch 41/50
# 51/51 [==============================] - 1s 10ms/step - loss: 0.9259 - accuracy: 0.6466 - val_loss: 1.3441 - val_accuracy: 0.5370 - lr: 0.0010
# Epoch 42/50
# 51/51 [==============================] - 1s 10ms/step - loss: 0.9292 - accuracy: 0.6460 - val_loss: 1.2902 - val_accuracy: 0.5444 - lr: 0.0010
# Epoch 43/50
# 51/51 [==============================] - 1s 11ms/step - loss: 0.8268 - accuracy: 0.6849 - val_loss: 1.2211 - val_accuracy: 0.5731 - lr: 4.0000e-04
# Epoch 44/50
# 51/51 [==============================] - 1s 10ms/step - loss: 0.7902 - accuracy: 0.6929 - val_loss: 1.2577 - val_accuracy: 0.5648 - lr: 4.0000e-04
# Epoch 45/50
# 51/51 [==============================] - 1s 12ms/step - loss: 0.7660 - accuracy: 0.7003 - val_loss: 1.2395 - val_accuracy: 0.5759 - lr: 4.0000e-04
# Epoch 46/50
# 51/51 [==============================] - 1s 10ms/step - loss: 0.7602 - accuracy: 0.7015 - val_loss: 1.2653 - val_accuracy: 0.5685 - lr: 4.0000e-04
# Epoch 47/50
# 51/51 [==============================] - 1s 12ms/step - loss: 0.7388 - accuracy: 0.7136 - val_loss: 1.2550 - val_accuracy: 0.5676 - lr: 4.0000e-04
# Epoch 48/50
# 51/51 [==============================] - 0s 9ms/step - loss: 0.6958 - accuracy: 0.7380 - val_loss: 1.2701 - val_accuracy: 0.5833 - lr: 1.6000e-04
# Epoch 49/50
# 51/51 [==============================] - 0s 8ms/step - loss: 0.6929 - accuracy: 0.7269 - val_loss: 1.2521 - val_accuracy: 0.5759 - lr: 1.6000e-04
# Epoch 50/50
# 51/51 [==============================] - 0s 8ms/step - loss: 0.6825 - accuracy: 0.7358 - val_loss: 1.2807 - val_accuracy: 0.5796 - lr: 1.6000e-04

# %%
# Định nghĩa hàm để vẽ đồ thị biểu diễn sự biến thiên của loss và accuracy của mô hình qua các epoch
def plot_history(history):
  # Cài đặt giao diện đồ thị và các thông số
    plt.style.use('seaborn-darkgrid')
    plt.rcParams.update({'font.size': 12})
    # Tạo một dãy số từ 1 đến số lượng epoch để sử dụng làm trục x của đồ thị
    epochs = range(1, len(history.history['accuracy']) + 1)

    # Tạo một hình vẽ với hai phần để hiển thị loss và accuracy
    plt.figure(figsize=(12, 6))

    # Phần đồ thị loss
    plt.subplot(1, 2, 1)
    plt.plot(epochs, history.history['loss'], 'bo-', label='Training Loss')
    plt.plot(epochs, history.history['val_loss'], 'ro-', label='Validation Loss')
    plt.title('Training & Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    # Phần đồ thị accuracy
    plt.subplot(1, 2, 2)
    plt.plot(epochs, history.history['accuracy'], 'bo-', label='Training Accuracy')
    plt.plot(epochs, history.history['val_accuracy'], 'ro-', label='Validation Accuracy')
    plt.title('Training & Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    # Sắp xếp các phần của đồ thị một cách hợp lý
    plt.tight_layout()
    plt.show()

# %%
plot_history(history_lstm)

# %%
plot_history(history_cnn)

# %%
y_pred_lstm = np.argmax(model_lstm.predict(x_test_reshaped), axis=1)
y_pred_cnn = np.argmax(model_cnn.predict(x_test_reshaped), axis=1)
y_test_labels = np.argmax(y_test, axis=1)
# Out:
# 34/34 [==============================] - 0s 6ms/step
# 34/34 [==============================] - 1s 11ms/step

# %% [markdown]
# Tạo ra ma trận nhầm lần (Confusion Matrix) :
# Ma trận này giúp:
#  - Đánh giá hiệu suất mô hình.
#  - Phát hiện các mẫu dữ liệu bị phân loại sai.
#  - Tối ưu hóa mô hình.

# %%
# Tạo ma trận nhầm lẫn cho mô hình LSTM
# Tạo DataFrame từ ma trận nhầm lẫn với index và columns được đặt theo các nhãn từ encoder
cm_lstm = confusion_matrix(y_test_labels, y_pred_lstm)
cm_lstm_df = pd.DataFrame(cm_lstm, index=encoder.categories_[0], columns=encoder.categories_[0])

plt.figure(figsize=(10, 8))
sns.heatmap(cm_lstm_df, annot=True, cmap='Purples', fmt='d', cbar=False)
plt.title('Confusion Matrix - LSTM Model')
plt.xlabel('Predicted Labels')
plt.ylabel('Accuracy Labels')
plt.show()

# %%
# Tạo ma trận nhầm lẫn cho mô hình CNN
# Tạo DataFrame từ ma trận nhầm lẫn với index và columns được đặt theo các nhãn từ encoder
cm_cnn = confusion_matrix(y_test_labels, y_pred_cnn)
cm_cnn_df = pd.DataFrame(cm_cnn, index=encoder.categories_[0], columns=encoder.categories_[0])

plt.figure(figsize=(10, 8))
sns.heatmap(cm_cnn_df, annot=True, cmap='Purples', fmt='d', cbar=False)
plt.title('Confusion Matrix - CNN Model')
plt.xlabel('Predicted Labels')
plt.ylabel('Accuracy Labels')
plt.show()

# %%
# Đánh giá hiệu suất của mô hình LSTM trên tập dữ liệu kiểm tra và in ra giá trị của loss và accuracy
loss_lstm, accuracy_lstm = model_lstm.evaluate(x_test_reshaped, y_test)
print("LSTM Model - Loss: {:.4f}, Accuracy: {:.2f}%".format(loss_lstm, accuracy_lstm * 100))
# Out:
# 34/34 [==============================] - 0s 3ms/step - loss: 1.1254 - accuracy: 0.6806
# LSTM Model - Loss: 1.1254, Accuracy: 68.06%

# %%
# Đánh giá hiệu suất của mô hình CNN trên tập dữ liệu kiểm tra và in ra giá trị của loss và accuracy
loss_cnn, accuracy_cnn = model_cnn.evaluate(x_test_reshaped, y_test)
print("CNN Model - Loss: {:.4f}, Accuracy: {:.2f}%".format(loss_cnn, accuracy_cnn * 100))
# Out:
# 34/34 [==============================] - 0s 4ms/step - loss: 1.2807 - accuracy: 0.5796
# CNN Model - Loss: 1.2807, Accuracy: 57.96%

# %%
# Chỉnh lại nhãn sau khi dự đoán từ số sang chữ
labels_mapping = {0: 'neutral',1: 'calm', 2: 'happy', 3: 'sad', 4: 'angry', 5: 'fear', 6: 'disgust', 7: 'surprise'}

# Dự đoán nhãn từ chỉ số dự đoán của mô hình LSTM và CNN
y_pred_lstm_labels = [labels_mapping[idx] for idx in y_pred_lstm]
y_pred_cnn_labels = [labels_mapping[idx] for idx in y_pred_cnn]
y_test_labels = [labels_mapping[idx] for idx in y_test_labels]

# %%
# Tạo và in ra báo cáo phân loại, so sánh giữa nhãn thực tế và nhãn dự đoán của mô hình LSTM
print("LSTM Model Classification Report:")
print(classification_report(y_test_labels, y_pred_lstm_labels))
# Out:
# LSTM Model Classification Report:
#               precision    recall  f1-score   support
#
#        angry       0.63      0.62      0.63       160
#         calm       0.72      0.76      0.74       141
#      disgust       0.65      0.67      0.66       143
#         fear       0.53      0.43      0.48        76
#        happy       0.70      0.69      0.70       142
#      neutral       0.80      0.74      0.77       138
#          sad       0.66      0.69      0.68       147
#     surprise       0.68      0.73      0.71       133
#
#     accuracy                           0.68      1080
#    macro avg       0.67      0.67      0.67      1080
# weighted avg       0.68      0.68      0.68      1080

# %%
# Tạo và in ra báo cáo phân loại, so sánh giữa nhãn thực tế và nhãn dự đoán của mô hình CNN
print("CNN Model Classification Report:")
print(classification_report(y_test_labels, y_pred_cnn_labels))
# Out:
# CNN Model Classification Report:
#               precision    recall  f1-score   support
#
#        angry       0.48      0.48      0.48       160
#         calm       0.63      0.70      0.67       141
#      disgust       0.52      0.53      0.53       143
#         fear       0.31      0.21      0.25        76
#        happy       0.61      0.58      0.59       142
#      neutral       0.69      0.62      0.65       138
#          sad       0.67      0.65      0.66       147
#     surprise       0.57      0.72      0.64       133
#
#     accuracy                           0.58      1080
#    macro avg       0.56      0.56      0.56      1080
# weighted avg       0.58      0.58      0.58      1080

# %%
# Lưu mô hình LSTM
model_lstm.save('/content/drive/MyDrive/Colab Notebooks/emotion_recognition_model_LSTM.h5')
